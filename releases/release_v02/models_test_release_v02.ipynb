# %%
import seaborn as sns
import numpy as np
import scipy
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display
# %pylab inline
import os
from __future__ import print_function
from __future__ import division
import os, sys
# hook up all scripts
sys.path.append(os.path.abspath('../scripts')) # if notebook in folder
sys.path.append(os.path.abspath('./scripts')) #if in root
sys.path.append(os.path.abspath('./releases/release_v02')) #if in root
import preprocessing_all_data_v02_prod as pts
import models_xgboost_release_v02 as mxr


os.chdir(pts.working_dir())
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Data encoded

# %%
reload(mxr)
data = mxr.data_brush_for_model('QUERETARO')
pd.set_option('display.max_columns', 999)
data.head()
# Out:
# Data encoded
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Agencia_ID</th>
#       <th>Canal_ID</th>
#       <th>Cliente_ID</th>
#       <th>Log_Demanda</th>
#       <th>Producto_ID</th>
#       <th>Ruta_SAK</th>
#       <th>brand</th>
#       <th>pieces</th>
#       <th>weight</th>
#       <th>Demanda_uni_equil_1</th>
#       <th>Dev_proxima_1</th>
#       <th>Dev_proxima_by_uni_1</th>
#       <th>Log_Demanda_1</th>
#       <th>Log_Demanda_Mean_Producto_ID_Cliente_ID_Agencia_ID_1</th>
#       <th>Log_Demanda_Mean_Producto_ID_Cliente_ID_Ruta_SAK_1</th>
#       <th>Log_Dev_proxima_1</th>
#       <th>Log_Venta_hoy_1</th>
#       <th>No_remains_1</th>
#       <th>No_remains_Mean_Producto_ID_Cliente_ID_Agencia_ID_1</th>
#       <th>No_remains_Mean_Producto_ID_Cliente_ID_Ruta_SAK_1</th>
#       <th>Venta_hoy_1</th>
#       <th>Venta_hoy_by_uni_1</th>
#       <th>Venta_uni_hoy_1</th>
# ...

# %%
y_eval, m1, m2 = mxr.model_building(data)

# %%
# data_test = pd.read_csv(pts.working_dir() + 'test.csv', index_col=0)
data_test.head()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Semana</th>
#       <th>Agencia_ID</th>
#       <th>Canal_ID</th>
#       <th>Ruta_SAK</th>
#       <th>Cliente_ID</th>
#       <th>Producto_ID</th>
#     </tr>
#     <tr>
#       <th>id</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>11</td>
#       <td>4037</td>
#       <td>1</td>
#       <td>2209</td>
#       <td>4639078</td>
#       <td>35305</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>11</td>
#       <td>2237</td>
#       <td>1</td>
#       <td>1226</td>
#       <td>4705135</td>
#       <td>1238</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>10</td>
#       <td>2045</td>
#       <td>1</td>
#       <td>2831</td>
#       <td>4549769</td>
#       <td>32940</td>
#     </tr>
#     <tr>
# ...

# %%
indexers = ['Semana', u'Agencia_ID',    u'Canal_ID',    u'Ruta_SAK',  u'Cliente_ID', u'Producto_ID']
test_len = data_test.shape[0]
data_test = pd.merge(data_test, y_eval.set_index(indexers[1:], append=True), 'inner',
                     left_on=indexers, right_index=True)
data_test.shape[0], test_len
# Out:
# (34136, 6999251)

# %%
data_test.head()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Semana</th>
#       <th>Agencia_ID</th>
#       <th>Canal_ID</th>
#       <th>Ruta_SAK</th>
#       <th>Cliente_ID</th>
#       <th>Producto_ID</th>
#       <th>Log_Demanda</th>
#     </tr>
#     <tr>
#       <th>id</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>504</th>
#       <td>10</td>
#       <td>22090</td>
#       <td>1</td>
#       <td>1006</td>
#       <td>4419855</td>
#       <td>1109</td>
#       <td>0.926801</td>
#     </tr>
#     <tr>
#       <th>680</th>
#       <td>11</td>
#       <td>22090</td>
#       <td>1</td>
#       <td>2809</td>
#       <td>1711635</td>
#       <td>35309</td>
#       <td>1.312291</td>
#     </tr>
#     <tr>
#       <th>1289</th>
#       <td>10</td>
#       <td>22090</td>
# ...
